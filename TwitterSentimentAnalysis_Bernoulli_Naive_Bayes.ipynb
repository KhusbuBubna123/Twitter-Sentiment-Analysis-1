# %% [markdown]
# <a href="https://colab.research.google.com/github/KhusbuBubna123/Reposity1/blob/main/TwitterSentimentAnalysis_Bernoulli_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,recall_score,f1_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#df= pd.read_csv("TDataset.csv",sep=',',names=['Sentiment','Tweet_ID','Date','Flag','User','Tweet'],encoding='latin-1',engine="python")
#df.head(8)

df= pd.read_csv("Twitter_Dataset_Binary.csv",sep=',',names=['Sentiment','Tweet_ID','Date','Flag','User','Tweet'],encoding='latin-1')
df.head(8)

#(0 = negative, 4 = positive)
# Out:
#    Sentiment    Tweet_ID                          Date      Flag  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6          0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7          0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
#
#               User                                              Tweet
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
# 5         joy_wolf                      @Kwesidei not the whole crew
# 6          mybirch                                        Need a hug
# 7             coZZ  @LOLTrish hey  long time no see! Yes.. Rains a...

# %%
df.tail()
# Out:
#          Sentiment    Tweet_ID                          Date      Flag  \
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     User                                              Tweet
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...

# %%
df.shape
# Out:
# (1600000, 6)

# %%
df.columns
# Out:
# Index(['Sentiment', 'Tweet_ID', 'Date', 'Flag', 'User', 'Tweet'], dtype='object')

# %%
#pd.set_option('display.max_rows', None) #Display all the rows.

# %% [markdown]
# #Exporatory Data Anlysis.

# %%
df['Sentiment'].value_counts() #(0 = negative, 4 = positive)
# Out:
# Sentiment
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
df.loc[df['Sentiment'] == 0] #Negative Sentiments
# Out:
#         Sentiment    Tweet_ID                          Date      Flag  \
# 0               0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1               0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2               0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3               0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4               0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 799995          0  2329205009  Thu Jun 25 10:28:28 PDT 2009  NO_QUERY
# 799996          0  2329205038  Thu Jun 25 10:28:28 PDT 2009  NO_QUERY
# 799997          0  2329205473  Thu Jun 25 10:28:30 PDT 2009  NO_QUERY
# 799998          0  2329205574  Thu Jun 25 10:28:30 PDT 2009  NO_QUERY
# 799999          0  2329205794  Thu Jun 25 10:28:31 PDT 2009  NO_QUERY
#
#                    User                                              Tweet
# 0       _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1         scotthamilton  is upset that he can't update his Facebook by ...
# 2              mattycus  @Kenichan I dived many times for the ball. Man...
# 3               ElleCTF    my whole body feels itchy and like its on fire
# 4                Karoli  @nationwideclass no, it's not behaving at all....
# ...                 ...                                                ...
# 799995         dandykim  Sick  Spending my day laying in bed listening ...
# 799996          bigenya                                    Gmail is down?
# 799997         LeeLHoke                      rest in peace Farrah! So sad
# 799998     davidlmulder  @Eric_Urbane Sounds like a rival is flagging y...
# 799999       tpchandler  has to resit exams over summer...  wishes he w...
#
# [800000 rows x 6 columns]

# %%
df.loc[df['Sentiment'] == 4] #Positive Sentiments
#(0 = negative, 4 = positive)
# Out:
#          Sentiment    Tweet_ID                          Date      Flag  \
# 800000           4  1467822272  Mon Apr 06 22:22:45 PDT 2009  NO_QUERY
# 800001           4  1467822273  Mon Apr 06 22:22:45 PDT 2009  NO_QUERY
# 800002           4  1467822283  Mon Apr 06 22:22:46 PDT 2009  NO_QUERY
# 800003           4  1467822287  Mon Apr 06 22:22:46 PDT 2009  NO_QUERY
# 800004           4  1467822293  Mon Apr 06 22:22:46 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     User                                              Tweet
# 800000             ersle       I LOVE @Health4UandPets u guys r the best!!
# 800001          becca210  im meeting up with one of my besties tonight! ...
# 800002         Wingman29  @DaRealSunisaKim Thanks for the Twitter add, S...
# 800003         katarinka  Being sick can be really cheap when it hurts t...
# 800004       _EmilyYoung    @LovesBrooklyn2 he has that effect on everyone
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [800000 rows x 6 columns]

# %%
# Tweet length feature

df['Tweet_Length'] = df['Tweet'].apply(len)
df.head()
# Out:
#    Sentiment    Tweet_ID                          Date      Flag  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#               User                                              Tweet  \
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
#
#    Tweet_Length
# 0           115
# 1           111
# 2            89
# 3            47
# 4           111

# %%
# Longest Tweet.
max_length=df['Tweet_Length'].max()
df.loc[df['Tweet_Length'] == max_length, 'Tweet'].values[0]
# Out:
# '@catfish_ohm à¹\x80à¸\x84à¹\x89à¸²à¹\x83à¸«à¹\x89à¸?à¸²à¸£à¹\x8cà¸\x95à¸¹à¸\x99à¸?à¸¸à¹\x82à¸£à¸°(à¸ªà¸±à¸ªà¹\x86+à¸¢à¸¹à¸£à¸´à¹?à¸?à¹\x84à¸\x94à¹\x89à¹?à¸\x97à¸\x99à¸\x99à¸°à¸\x9eà¸\xadà¸\x94à¸µà¸¡à¸´à¹\x82à¸?à¸°à¸«à¸§à¸\x87(à¸\x82à¸\x99à¸²à¸\x94à¹\x80à¸\x9fà¸´à¸\x99à¹?à¸?à¸¢à¸±à¸\x87à¹\x80à¸\x84à¸¢à¹\x83à¸«à¹\x89à¹\x84à¸¡à¹\x88à¹\x83à¸\x8aà¹\x88à¹\x80à¸«à¸£à¸\xad.à¹?à¸\x95à¹\x88à¸\x8aà¹\x88à¸²à¸\x87à¹\x80à¸«à¸\xadà¸°à¸£à¸²à¸¢à¸\x99à¸±à¹\x89à¸\x99à¹\x80à¸\x82à¸²à¹\x82à¸¡à¹\x80à¸\xadà¸°à¸?à¸§à¹\x88à¸²à¸\x9bà¸¥à¸²à¹?à¸¡à¸§à¹\x80à¸¢à¸\xadà¸° = '

# %%
print("Length of Longest Tweet",max_length)
# Out:
# Length of Longest Tweet 374

# %%
# Shortest Tweet
min_length=df['Tweet_Length'].min()
df.loc[df['Tweet_Length'] == min_length, 'Tweet'].values[0]
# Out:
# ' just '

# %%
print("Length of Shortest Tweet",df['Tweet_Length'].min())
# Out:
# Length of Shortest Tweet 6

# %% [markdown]
# #Text Preprocessing.

# %% [markdown]
# #Removing punctuation and converting to lower case.

# %%
def remove_punct(text):
    return ''.join(ch for ch in text if ch not in string.punctuation)

def convert_lower(text):
    return text.lower()

df['Tweet_clean'] = df['Tweet'].apply(remove_punct)
df['Tweet_clean'] = df['Tweet_clean'].apply(convert_lower)
df.head(8)
# Out:
#    Sentiment    Tweet_ID                          Date      Flag  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6          0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7          0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
#
#               User                                              Tweet  \
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
# 5         joy_wolf                      @Kwesidei not the whole crew
# 6          mybirch                                        Need a hug
# 7             coZZ  @LOLTrish hey  long time no see! Yes.. Rains a...
#
#    Tweet_Length                                        Tweet_clean
# 0           115  switchfoot httptwitpiccom2y1zl  awww thats a b...
# 1           111  is upset that he cant update his facebook by t...
# 2            89  kenichan i dived many times for the ball manag...
# 3            47    my whole body feels itchy and like its on fire
# 4           111  nationwideclass no its not behaving at all im ...
# 5            29                       kwesidei not the whole crew
# 6            11                                        need a hug
# 7            99  loltrish hey  long time no see yes rains a bit...

# %% [markdown]
# #Splitting into Train and Test Data

# %%
X = df['Tweet_clean'].values
Y = df['Sentiment'].values.astype(int)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=10)

print('Train size:', len(X_train))
print('Test  size:', len(X_test))
# Out:
# Train size: 1280000
# Test  size: 320000

# %% [markdown]
# #Vectorisation — Bag of Words (CountVectorizer)

# %%
#Count Vectorize and remove stopwords.
CV = CountVectorizer(stop_words='english')
X_train_cv = CV.fit_transform(X_train)
X_test_cv  = CV.transform(X_test)

print('Vocabulary size:', len(CV.vocabulary_))
print('Train shape    :', X_train_cv.shape)
print('Test  shape    :', X_test_cv.shape)
# Out:
# Vocabulary size: 720874
# Train shape    : (1280000, 720874)
# Test  shape    : (320000, 720874)

# %%
feature_names = CV.get_feature_names_out()
print('Total features:', len(feature_names))
print('Sample feature tokens  :', feature_names[:100]) #Printing First 100 tokens from the Vocaborary.
# Out:
# Total features: 720874
# Sample feature tokens  : ['00' '000' '0000' '00000' '0000000000' '00000001' '0000001' '0000014'
#  '000009260gbs' '0000abcd' '0000ff' '0001' '0001110101001010000111'
#  '0001am' '0001t' '0002' '0003' '0005' '00055' '00055gbmin' '0005am'
#  '0005mm' '0007' '0009' '000aah' '000h' '000martha' '000month' '000quot'
#  '000s' '000webhost' '001' '0010' '0010utc' '0010x0010'
#  '0011000100101011001100010011110100110010' '0012' '0014' '0019' '001quot'
#  '001sec' '002' '0020' '00202' '002345' '0029' '003' '0030' '0031' '0035'
#  '0036' '003r' '003ï' '004' '0045' '0047' '0049' '005' '0050' '0051'
#  '0054am' '0055gb60sec' '005603' '0058' '006' '0069' '007' '00711' '0074'
#  '007episode' '007heather007' '007hil' '007jbond' '007peter' '007wisdom'
#  '008' '0084' '00ff00' '00fieldsy' '00g' '00geneva' '00jon' '00k'
#  '00mathias' '00mony00' '00neji' '00pet00' '00pmpray' '00poloshawty'
#  '00ps' '00s' '00seve' '00vicky00' '00where' '01' '010' '0100' '01000'
#  '01000101' '0106']

# %% [markdown]
# #Training the model — Bernoulli Naive Bayes

# %%
NB = BernoulliNB(alpha=0.01) #alpha is used for Laplace smooothing.
NB.fit(X_train_cv, Y_train)
Y_Predict = NB.predict(X_test_cv)
Y_Predict
# Out:
# array([0, 0, 4, ..., 0, 0, 4])

# %%
#y_predict=y_predict.replace({0:"beningn",1:"Malignant"})
y_cat_variable = pd.Categorical(Y_Predict).rename_categories({0:"Negative Sentiment", 4:"Positive Sentiment"})
y_cat_variable

#(0 = negative, 4 = positive)
# Out:
# ['Negative Sentiment', 'Negative Sentiment', 'Positive Sentiment', 'Negative Sentiment', 'Positive Sentiment', ..., 'Positive Sentiment', 'Negative Sentiment', 'Negative Sentiment', 'Negative Sentiment', 'Positive Sentiment']
# Length: 320000
# Categories (2, object): ['Negative Sentiment', 'Positive Sentiment']

# %% [markdown]
# #Accuracy

# %%
print(f'Bernoulli Naive Bayes Accuracy using Count Vectorizer: {accuracy_score(Y_test, Y_Predict)*100:.2f}%')
# Out:
# Bernoulli Naive Bayes Accuracy using Count Vectorizer: 74.89%

# %% [markdown]
# #F1 score

# %%
f1_score=f1_score(Y_Predict,Y_test,pos_label=4)
f1_score
# Out:
# 0.7451837102235976

# %%
recall=recall_score(Y_Predict,Y_test,pos_label=4)
recall
# Out:
# 0.7570463140127429

# %%
print(classification_report(Y_test, Y_Predict, target_names=['Positive Sentiment', 'Negative Sentiment']))
# Out:
#                     precision    recall  f1-score   support
#
# Positive Sentiment       0.74      0.76      0.75    159835
# Negative Sentiment       0.76      0.73      0.75    160165
#
#           accuracy                           0.75    320000
#          macro avg       0.75      0.75      0.75    320000
#       weighted avg       0.75      0.75      0.75    320000

# %% [markdown]
# #Printing Confusion Matrix.

# %%
cm = pd.DataFrame(
    confusion_matrix(Y_test, Y_Predict),
    index=['Actual Positive', 'Actual Negative'],
    columns=['Predicted Positive', 'Predicted Negative'],
)
cm
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive              122123               37712
# Actual Negative               42654              117511

# %% [markdown]
# #Testing on a New Tweet.

# %%
def classify_tweet(tweet):
    cleaned  = remove_punct(tweet)
    cleaned = convert_lower(cleaned)
    features = CV.transform([cleaned])
    Predict = NB.predict(features)[0]
    if(Predict == 0):
      Sentiment='Negative Sentiment'
    elif(Predict== 4):
      Sentiment='Positive Sentiment'
    return Sentiment
#(0 = negative, 4 = positive)

# %%
#Neutral Sentiment Tweet.
Tweet1='this comes from cabinet which has scholars like modi smriti and hema time introspect'

# %%
sentiment=classify_tweet(Tweet1)
print(sentiment)
# Out:
# Positive Sentiment

# %%
Tweet2='talk all the nonsense and continue all the drama will vote for modi'

# %%
sentiment=classify_tweet(Tweet2)
print(sentiment)
# Out:
# Positive Sentiment

# %%
#Neutral Sentiement.
Tweet2="one vote can make all the difference anil kapoor answers modis election 2019 clarion call extends support his vote kar campaign"

# %%
sentiment=classify_tweet(Tweet2)
print(sentiment)
# Out:
# Positive Sentiment

# %%
Tweet3="with firm belief the leadership shri narendra modi bjp entering into politics given form file nomination for the khammam parliamentary seat proceeding khammam today"
#negative Tweet Sentiment.

# %%
sentiment=classify_tweet(Tweet3)
print(sentiment)
# Out:
# Positive Sentiment

# %%
Tweet4="	hope tuthukudi people would prefer honest well behaved nationalist courageous likly minister modi cabinet vote benifit thuthukudi"
#Positive Tweet Sentiment

# %%
sentiment=classify_tweet(Tweet4)
print(sentiment)
# Out:
# Negative Sentiment

# %%
#Positive Sentiment Tweet.
Tweet5='answer who among these the most powerful world leader today trump putin modi may'

# %%
sentiment=classify_tweet(Tweet5)
print(sentiment)
# Out:
# Positive Sentiment

# %% [markdown]
# #Vectorisation —TF-IDF Vectorization.

# %%
tf = TfidfVectorizer()

X_train_tf = tf.fit_transform(X_train[:100]).toarray()
X_test_tf  = tf.transform(X_test).toarray()

# FIX 4: get_feature_names_out() replaces deprecated get_feature_names()
print('TF-IDF features:', len(tf.get_feature_names_out()))
print('Train shape     :', X_train_tf.shape)
print('Test  shape     :', X_test_tf.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10777/2160843888.py in <cell line: 0>()
#       1 tf = TfidfVectorizer()
#       2
# ----> 3 X_train_tf = tf.fit_transform(X_train[:100]).toarray()
#       4 X_test_tf  = tf.transform(X_test).toarray()
#       5
#
# NameError: name 'X_train' is not defined

# %%
NB = BernoulliNB(alpha=0.01) #alpha is used for Laplace smooothing.
NB.fit(X_train_tf, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10131/911508064.py in <cell line: 0>()
#       1 NB = BernoulliNB(alpha=0.01) #alpha is used for Laplace smooothing.
# ----> 2 NB.fit(X_train_tf, Y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     733             Returns the instance itself.
#     734         """
# --> 735         X, y = self._check_X_y(X, y)
#     736         _, n_features = X.shape
#     737
#
# /usr/local/lib/python3.12/dist-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y, reset)
#    1192
#    1193     def _check_X_y(self, X, y, reset=True):
# -> 1194         X, y = super()._check_X_y(X, y, reset=reset)
#    1195         if self.binarize is not None:
#    1196             X = binarize(X, threshold=self.binarize)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y, reset)
#     579     def _check_X_y(self, X, y, reset=True):
#     580         """Validate X and y in fit methods."""
# --> 581         return validate_data(self, X, y, accept_sparse="csr", reset=reset)
#     582
#     583     def _update_class_log_prior(self, class_prior=None):
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2959             y = check_array(y, input_name="y", **check_y_params)
#    2960         else:
# -> 2961             X, y = check_X_y(X, y, **check_params)
#    2962         out = X, y
#    2963
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1387     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1388
# -> 1389     check_consistent_length(X, y)
#    1390
#    1391     return X, y
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     473     uniques = np.unique(lengths)
#     474     if len(uniques) > 1:
# --> 475         raise ValueError(
#     476             "Found input variables with inconsistent numbers of samples: %r"
#     477             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [100, 1280000]

# %%
Y_Predict = NB.predict(X_test_tf)
Y_Predict

# %%
accuracy = accuracy_score(Y_test, Y_Predict) * 100
print(f'MultinomialNB Accuracy: {accuracy:.2f}%')

# %%
f1_score=f1_score(Y_Predict,Y_test,pos_label=4)
f1_score

# %%
recall=recall_score(Y_Predict,Y_test,pos_label=4)
recall

# %%
print(classification_report(Y_test, Y_Predict, target_names=['Positive Sentiment', 'Negative Sentiment']))

# %%
cm = pd.DataFrame(
    confusion_matrix(Y_test, Y_Predict),
    index=['Actual Positive', 'Actual Negative'],
    columns=['Predicted Positive', 'Predicted Negative'],
)
cm
# Out:
#                  Predicted Positive  Predicted Negative
# Actual Positive              122123               37712
# Actual Negative               42654              117511

# %% [markdown]
# #Testing on a New Tweet.

# %%
def classify_tweet(tweet):
    cleaned  = remove_punct(tweet)
    cleaned = convert_lower(cleaned)
    features = CV.transform([cleaned])
    Predict = NB.predict(features)[0]
    if(Predict == '0'):
      Sentiment='Negative Sentiment'
    elif(Predict=='4'):
      Sentiment="Positive Sentiment"
    return Sentiment
#(0 = negative, 4 = positive)

# %%
#Neutral Sentiment Tweet.
Tweet1='this comes from cabinet which has scholars like modi smriti and hema time introspect'

# %%
sentiment=classify_tweet(Tweet1)
print(sentiment)

# %%
#Neutral Sentiement.
Tweet2="one vote can make all the difference anil kapoor answers modis election 2019 clarion call extends support his vote kar campaign"

# %%
sentiment=classify_tweet(Tweet2)
print(sentiment)

# %%
Tweet3="with firm belief the leadership shri narendra modi bjp entering into politics given form file nomination for the khammam parliamentary seat proceeding khammam today"
#negative Tweet Sentiment.

# %%
sentiment=classify_tweet(Tweet3)
print(sentiment)

# %%
Tweet4="	hope tuthukudi people would prefer honest well behaved nationalist courageous likly minister modi cabinet vote benifit thuthukudi"
#Positive Tweet Sentiment

# %%
sentiment=classify_tweet(Tweet4)
print(sentiment)

# %%
#Positive Sentiment Tweet.
Tweet5='answer who among these the most powerful world leader today trump putin modi may'

# %%
sentiment=classify_tweet(Tweet5)
print(sentiment)
